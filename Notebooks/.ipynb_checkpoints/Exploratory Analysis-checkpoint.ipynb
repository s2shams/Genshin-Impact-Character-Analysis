# %%
# importing necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
import pandasql as ps
from sqlalchemy import text
from matplotlib.colors import Normalize

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading in the tables

# %%
abyss = pd.read_csv('csv_files/abyss.csv')
abyss.rename(columns={'Version ->': 'Name'}, inplace=True)
abyss.head()
# Out:
#            Name  Rarity  Vision    1.5   1.6     2   2.1   2.2   2.3   2.4  \
# 0        Albedo       5     Geo  55.56  27.6  51.3  47.4  44.1  61.4  42.0
# 1     Alhaitham       5  Dendro    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2         Amber       4    Pyro   1.90   1.5   0.3   0.2   0.7   0.8   1.0
# 3  Arataki Itto       5     Geo    NaN   NaN   NaN   NaN   NaN   NaN  39.0
# 4        Baizhu       5  Dendro    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...     3   3.1   3.2   3.3   3.4   3.5   3.6   3.7   3.8  Average usage
# 0  ...  24.6  17.9  15.7  30.1   8.6   5.4   7.9   5.9   3.6          30.88
# 1  ...   NaN   NaN   NaN   NaN  56.0  56.6  57.6  40.9  64.8          55.18
# 2  ...   0.2   0.4   0.5   1.0   0.2   0.1   0.1   0.2   0.2           0.56
# 3  ...  17.3  16.9  15.2  39.6  10.6   6.4  11.1   8.2   5.3          20.44
# 4  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN  53.5  59.4          56.45
#
# [5 rows x 24 columns]

# %%
elemental_usage = pd.read_csv('csv_files/elemental_usage.csv')
elemental_usage
# Out:
#     Vision    1.5    1.6      2    2.1    2.2    2.3    2.4    2.5    2.6  \
# 0    Anemo  59.38  61.58  40.90  41.40  39.97  33.43  26.50  26.77  36.77
# 1     Cryo  35.01  28.76  26.91  28.50  30.75  27.52  30.24  21.27  33.97
# 2   Dendro    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  Electro  12.24   7.74   5.90  11.99  18.77  19.46  16.43  23.90  15.82
# 4      Geo  40.72  33.52  40.70  38.12  34.40  39.02  29.57  38.43  12.83
# 5    Hydro  37.70  34.50  43.48  41.25  41.58  42.62  47.80  43.20  51.28
# 6     Pyro  29.57  27.14  21.01  24.10  27.48  25.13  23.70  24.47  12.58
#
#    ...      3    3.1    3.2    3.3    3.4    3.5    3.6    3.7    3.8  \
# 0  ...  24.01  20.07  19.64  16.52  15.30  12.42  11.72  15.99  12.67
# 1  ...  24.49  20.43  17.50  11.22   5.63  11.10   8.17  10.80  10.41
# 2  ...  10.70  20.45  28.47  29.37  33.86  33.86  29.40  26.50  30.25
# 3  ...  14.24  16.90  19.66  19.47  17.09  18.55  17.90  15.10  16.42
# 4  ...  20.57  16.23  15.57  28.44  14.84  11.73  12.77  12.09   9.01
# 5  ...  46.86  34.49  39.00  37.17  31.66  35.21  39.61  31.84  42.52
# 6  ...  27.64  20.98  18.55  22.12  16.21  22.60  16.65  22.05  12.92
#
#    Average usage
# 0      28.682500
# 1      21.014500
# 2      26.984444
# 3      15.813000
# 4      25.049000
# 5      40.315000
# 6      22.821000
#
# [7 rows x 22 columns]

# %%
characters = pd.read_csv('csv_files/characters.csv')
characters.head()
# Out:
#            Name  rarity  vision weapon_type       constellation birthday  \
# 0        Albedo       5     Geo       Sword  Princeps Cretaceus   13-Sep
# 1     Alhaitham       5  Dendro       Sword       Vultur Volans   11-Feb
# 2         Amber       4    Pyro         Bow               Lepus   10-Aug
# 3  Arataki Itto       5     Geo    Claymore    Taurus Iracundus   01-Jun
# 4        Baizhu       5  Dendro    Catalyst           Lagenaria   25-Apr
#
#                  special_dish          affiliation     HP  ATK  DEF  \
# 0              Woodland Dream  Knights of Favonius  13225  251  876
# 1          Ideal Circumstance     Sumeru Akademiya  13348  313  781
# 2  Outrider's Champion Steak!  Knights of Favonius   9461  223  600
# 3           Way of the Strong         Arataki Gang  12858  227  959
# 4          Heat-Quelling Soup        Bubu Pharmacy  13348  192  499
#
#      Ascension Stat Ascension Stat Value Element    Weapon     Nation  \
# 0     Geo DMG Bonus               28.80%     Geo     Sword  Mondstadt
# 1  Dendro DMG Bonus               28.80%  Dendro     Sword     Sumeru
# 2               ATK               24.00%    Pyro       Bow  Mondstadt
# 3         CRIT Rate               19.20%     Geo  Claymore    Inazuma
# 4                HP               28.80%  Dendro  Catalyst      Liyue
#
#       Model Type
# 0    Medium Male
# 1      Tall Male
# 2  Medium Female
# 3      Tall Male
# 4      Tall Male

# %%
revenue = pd.read_csv('csv_files/revenue.csv')
revenue = revenue.astype({'1':'int', '2':'int', '3':'int', '4':'int'})
for col in revenue.columns:
    if col != 'Name' and col != 'Vision':
        revenue[col] /= 100000
revenue = revenue.round(decimals=2)
revenue.head()
# Out:
#      Name   Vision       1       2       3    4   Total
# 0  Hu Tao     Pyro  124.82  252.27  188.49  0.0  565.57
# 1  Keqing  Electro   95.06    0.00    0.00  0.0   95.06
# 2  Kazuha    Anemo   98.07  216.07  126.50  0.0  440.65
# 3  Nahida   Dendro  314.69  200.82    0.00  0.0  515.51
# 4   Yelan    Hydro  233.13  277.08    0.00  0.0  510.20

# %% [markdown]
# # Questions I wish to answer:
# 1. What character/element had the highest overall usage rate/revenue? (and lowest)
# 3. Do characters generally perform better on their rerun banners?
# 4. Do the usage rate of elements have a pattern/trend?
# 5. Is there anything common between the top 5 most used characters?
# 6. What nation has the strongest characters? (determined by flat stats)
# 7. What affiliation is the most common within the playable characters? (i.e Knights of Favonius, Arataki Gang etc.)

# %% [markdown]
# ### What character had the highest overall usage rate/revenue? (and lowest)

# %%
# Character with the highest average usage rate:

query = '''
SELECT Name
FROM abyss
WHERE `Average usage` = (SELECT MAX(`Average usage`) FROM abyss);
'''
ps.sqldf(query, locals())
# Out:
#      Name
# 0  Nahida

# %%
# Character with the lowest average usage rate:

query = '''
SELECT Name
FROM abyss
WHERE `Average usage` = (SELECT MIN(`Average usage`) FROM abyss);
'''
ps.sqldf(query, locals())
# Out:
#       Name
# 0  Candace

# %%
# Character with the highest TOTAL revenue:

query = '''
SELECT Name
FROM revenue
WHERE Total = (SELECT MAX(Total) FROM revenue);
'''
ps.sqldf(query, locals())
# Out:
#      Name
# 0  Shogun

# %%
# Character with the Lowest TOTAL revenue:

query = '''
SELECT Name
FROM revenue
WHERE Total = (SELECT MIN(Total) FROM revenue);
'''
ps.sqldf(query, locals())
# Out:
#      Name
# 0  Baizhu

# %% [markdown]
# #### Creating a new column in the revenue table to contain the revenue per banner

# %%
revenue['revenue per banner'] = 0

for index, char in enumerate(revenue['Name']):
    num = 0
    
    if revenue['1'][index] != 0:
        num += 1
    if revenue['2'][index] != 0:
        num += 1
    if revenue['3'][index] != 0:
        num += 1
    if revenue['4'][index] != 0:
        num += 1
    revenue['revenue per banner'][index] = revenue['Total'][index] / num
revenue['revenue per banner'] = revenue['revenue per banner'].round(2)
revenue.head()
# Out:
#      Name   Vision       1       2       3    4   Total  revenue per banner
# 0  Hu Tao     Pyro  124.82  252.27  188.49  0.0  565.57              188.52
# 1  Keqing  Electro   95.06    0.00    0.00  0.0   95.06               95.06
# 2  Kazuha    Anemo   98.07  216.07  126.50  0.0  440.65              146.88
# 3  Nahida   Dendro  314.69  200.82    0.00  0.0  515.51              257.76
# 4   Yelan    Hydro  233.13  277.08    0.00  0.0  510.20              255.10

# %%
# Character with the highest revenue per banner:

query = '''
SELECT Name
FROM revenue
WHERE `revenue per banner` = (SELECT MAX(`revenue per banner`) FROM revenue);
'''
ps.sqldf(query, locals())
# Out:
#      Name
# 0  Shogun

# %%
# Character with the lowest revenue per banner:

query = '''
SELECT Name
FROM revenue
WHERE `revenue per banner` = (SELECT MIN(`revenue per banner`) FROM revenue);
'''
ps.sqldf(query, locals())
# Out:
#      Name
# 0  Albedo

# %%
revenue.drop(columns=['Total', 'revenue per banner', 'Vision']).plot(x='Name', kind='bar', stacked=True, title='Character revenue', figsize=(15,10))
plt.xlabel('Character', fontsize=20)
plt.ylabel('Revenue/$100,1000', fontsize=20)
plt.show()

df2 = revenue.drop(columns=['Total', '1', '2', '3', '4','Vision'])
cmap = plt.get_cmap('viridis')
norm = Normalize(vmin=min(df2['revenue per banner']), vmax=max(df2['revenue per banner']))
colors = [cmap(norm(value)) for value in df2['revenue per banner']]

plt.figure(figsize=(20,10))
plt.bar(df2['Name'], df2['revenue per banner'], color=colors)
plt.title('Character revenue per banner', fontsize = 20)
plt.xlabel('Character', fontsize=20)
plt.ylabel('Revenue/$100,1000', fontsize=20)
plt.xticks(rotation='vertical')

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm)

plt.show()

# %% [markdown]
# #### From looking at the first bar chart above, we can see that some characters generate more revenue during their reruns and some characters don't. There doesn't seem to a specific trend, it mainly depends on the character.
#
# The second bar chart allows us the clearly see more popular 5 star characters

# %% [markdown]
# ### What element had the highest overall usage rate/revenue? (and lowest)

# %%
# Element with the highest average usage rate:

query = '''
SELECT Vision
FROM elemental_usage
WHERE `Average usage` = (SELECT MAX(`Average usage`) FROM elemental_usage);
'''
ps.sqldf(query, locals())
# Out:
#   Vision
# 0  Hydro

# %%
# Element with the lowest average usage rate:

query = '''
SELECT Vision
FROM elemental_usage
WHERE `Average usage` = (SELECT MIN(`Average usage`) FROM elemental_usage);
'''
ps.sqldf(query, locals())
# Out:
#     Vision
# 0  Electro

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

elemental_colors = {
    'Pyro': 'indianred',
    'Hydro': 'steelblue',
    'Cryo': 'lightblue',
    'Dendro': 'yellowgreen',
    'Anemo': 'mediumaquamarine',
    'Geo': 'goldenrod',
    'Electro': 'darkorchid'
}

nation_colors = {
    'Mondstadt' : 'mediumaquamarine',
    'Inazuma' : 'blueviolet',
    'Sumeru' : 'forestgreen',
    'Snezhnaya' : 'steelblue',
    'Liyue' : 'darkgoldenrod'
}

elements = []
elements2 = []
cols = ['Pyro', 'Hydro', 'Cryo', 'Dendro', 'Anemo', 'Geo', 'Electro']

# Average revenue chart
for vision in cols:
    elements.append(revenue.loc[revenue['Vision'] == vision, 'Total'].mean())       
df = pd.DataFrame({'Vision' : cols,
                  'Revenue': elements})

axs[0].bar(df['Vision'], df['Revenue'], color=[elemental_colors[element] for element in df['Vision']])
axs[0].set_title("Average Revenue By Element")
axs[0].set_ylabel("Revenue/$100,000")

# Total revenue chart
for vision in cols:
    elements2.append(revenue.loc[revenue['Vision'] == vision, 'Total'].sum())
df = pd.DataFrame({'Vision': cols,
                  'Revenue': elements2})

axs[1].bar(df['Vision'], df['Revenue'], color=[elemental_colors[element] for element in df['Vision']])
axs[1].set_title("Total Revenue By Element")
axs[1].set_ylabel("Revenue/$100,000")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Element usage rate through time

# %%
temp = elemental_usage.drop(columns=['Average usage']).transpose()
temp.columns = temp.iloc[0]
temp = temp[1:]

# usage rate through time
plt.figure(figsize=(20, 10))
colors = ['mediumaquamarine', 'lightblue', 'yellowgreen', 'darkorchid', 'goldenrod', 'steelblue', 'indianred']

for index, col in enumerate(temp.columns):
    plt.plot(temp.index, temp[col], label = col, color=colors[index % len(colors)] )

plt.xlabel('Version', fontsize=15)
plt.ylabel('Rate', fontsize=15)
plt.title('Usage rate', fontsize=15)
plt.legend()
plt.grid(True)

plt.show()

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].bar(elemental_usage['Vision'], elemental_usage['Average usage'], color=colors)
axs[0].set_ylabel('Rate', fontsize=10)
axs[0].set_title('Usage Rate Averaged By Versions', fontsize=10)
axs[0].grid(True)

# usage rated averaged by characters
temp = []

for vision in cols:
    temp.append(abyss.loc[abyss['Vision'] == vision, 'Average usage'].mean())

df = pd.DataFrame({'Vision' : cols,
                  'Usage': temp})
colors = ['indianred', 'steelblue', 'lightblue', 'yellowgreen', 'mediumaquamarine', 'goldenrod', 'darkorchid']
axs[1].bar(df['Vision'], df['Usage'], color=colors)
axs[1].set_ylabel('Rate', fontsize=10)
axs[1].set_title('Usage Rate Averaged By Characters', fontsize=10)
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### We can see that Hydro is the dominant and most used/popular element in the game. This makes sense due to how versatile hydro is. It can be used with practically every element due to how powerful each reaction is

# %% [markdown]
# ## What Nation Has The Strongest Characters?

# %%
characters.drop(columns=['weapon_type', 'vision'], inplace=True)
characters.head()
# Out:
#            Name  rarity       constellation birthday  \
# 0        Albedo       5  Princeps Cretaceus   13-Sep
# 1     Alhaitham       5       Vultur Volans   11-Feb
# 2         Amber       4               Lepus   10-Aug
# 3  Arataki Itto       5    Taurus Iracundus   01-Jun
# 4        Baizhu       5           Lagenaria   25-Apr
#
#                  special_dish          affiliation     HP  ATK  DEF  \
# 0              Woodland Dream  Knights of Favonius  13225  251  876
# 1          Ideal Circumstance     Sumeru Akademiya  13348  313  781
# 2  Outrider's Champion Steak!  Knights of Favonius   9461  223  600
# 3           Way of the Strong         Arataki Gang  12858  227  959
# 4          Heat-Quelling Soup        Bubu Pharmacy  13348  192  499
#
#      Ascension Stat Ascension Stat Value Element    Weapon     Nation  \
# 0     Geo DMG Bonus               28.80%     Geo     Sword  Mondstadt
# 1  Dendro DMG Bonus               28.80%  Dendro     Sword     Sumeru
# 2               ATK               24.00%    Pyro       Bow  Mondstadt
# 3         CRIT Rate               19.20%     Geo  Claymore    Inazuma
# 4                HP               28.80%  Dendro  Catalyst      Liyue
#
#       Model Type
# 0    Medium Male
# 1      Tall Male
# 2  Medium Female
# 3      Tall Male
# 4      Tall Male

# %%
fig, axs = plt.subplots(2, 2, figsize=(20, 10))

axs[0, 0].bar(characters['Weapon'].value_counts().index, characters['Weapon'].value_counts().values)
axs[0, 0].set_title('Weapon Distribution')
axs[0, 0].set_ylabel('Character Count')

axs[0, 1].bar(characters['Element'].value_counts().index, characters['Element'].value_counts().values, 
              color=[elemental_colors[element] for element in characters['Element'].value_counts().index])
axs[0, 1].set_title('Element Distribution')
axs[0, 1].set_ylabel('Character Count')

axs[1, 0].bar(characters['Model Type'].value_counts().index, characters['Model Type'].value_counts().values)
axs[1, 0].set_title('Model Distribution')
axs[1, 0].set_ylabel('Character Count')

axs[1, 1].bar(characters['Nation'].value_counts().index, characters['Nation'].value_counts().values, 
             color=[nation_colors[char] for char in characters['Nation'].value_counts().index])
axs[1, 1].set_title('Nation Distribution')
axs[1, 1].set_ylabel('Character Count')

plt.tight_layout()
plt.show()

# %%
query = '''
SELECT Name, Element, Weapon, ATK, DEF
FROM characters
WHERE Nation = 'Mondstadt';
'''
mondstadt = ps.sqldf(query, locals())

query = '''
SELECT Name, Element, Weapon, ATK, DEF
FROM characters
WHERE Nation = 'Liyue';
'''
liyue = ps.sqldf(query, locals())

query = '''
SELECT Name, Element, Weapon, ATK, DEF
FROM characters
WHERE Nation = 'Inazuma';
'''
inazuma = ps.sqldf(query, locals())

query = '''
SELECT Name, Element, Weapon, ATK, DEF
FROM characters
WHERE Nation = 'Sumeru';
'''
sumeru = ps.sqldf(query, locals())

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 10))
nations = [mondstadt, liyue, inazuma, sumeru]
nations1 = ['Mondstadt', 'Liyue', 'Inazuma', 'Sumeru']

for i, nation in enumerate(nations):
    row = i // 2
    col = i % 2

    for element, color in elemental_colors.items():
        subset = nation[nation['Element'] == element]
        axs[row, col].scatter(subset['DEF'], subset['ATK'], label=element, c=color, marker='o', edgecolor='black')
        
        for _, character in subset.iterrows():
            axs[row, col].annotate(character['Name'], (character['DEF'], character['ATK']), fontsize=8, ha='left')
        
    axs[row, col].set_xlabel('DEF')
    axs[row, col].set_ylabel('ATK')
    axs[row, col].set_title(nations1[i])
    axs[row, col].grid(True)
    if row == 0 and col == 0:
        axs[row, col].legend(title='Element')

plt.tight_layout()
plt.show()
